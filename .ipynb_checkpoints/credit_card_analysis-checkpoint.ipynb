# %% [markdown]
# # Credit Card Analysis of Czech Bank
#
# ### Authors:
# Nur Inna Alfianinda
#
# ### Description:
# The bank managers want to know, who is a good client (whom to offer some additional services) and who is a bad client (whom to watch carefully to minimize the bank loses). Fortunately, the bank stores data about their clients, the accounts (transactions within several months), the loans already granted, the credit cards issued. The bank managers hope to improve their understanding of customers and seek specific actions to improve services.
#
# ### Dataset: https://webpages.charlotte.edu/mirsad/itcs6265/group1/domain.html
#
# ### Outline:
# 1. Data Extraction
# 2. Data Cleaning
# 3. Exploratory Data Analysis
# 4. Data Preprocessing
# 4. Cluster Analysis

# %% [markdown]
# ### Objective:
# Using agglomerative and kmeans clustering algorithms to analyse the bank data in order to extrapolate from it the type of customer who makes a good candidate for a credit card.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Accounts Dataset

# %% [markdown]
# ### 1.1 Data Extraction

# %%
accounts_url='https://drive.google.com/file/d/1rZNBZW_YBQEWalGyL3-qtmX9c2xUMN1I/view?usp=sharing'
accounts_url='https://drive.google.com/uc?id=' + accounts_url.split('/')[-2]
df_accounts = pd.read_csv(accounts_url,sep=';')
df_accounts.head()
# Out:
#    account_id  district_id         frequency    date
# 0         576           55  POPLATEK MESICNE  930101
# 1        3818           74  POPLATEK MESICNE  930101
# 2         704           55  POPLATEK MESICNE  930101
# 3        2378           16  POPLATEK MESICNE  930101
# 4        2632           24  POPLATEK MESICNE  930102

# %% [markdown]
# ### 1.2 Data Cleaning

# %% [markdown]
# #### 1.2.1 Understanding the Dataset

# %%
df_accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   account_id   4500 non-null   int64
#  1   district_id  4500 non-null   int64
#  2   frequency    4500 non-null   object
#  3   date         4500 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 140.8+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 1.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_accounts.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 1.2.3 Convert Data Type

# %%
df_accounts.dtypes
# Out:
# account_id      int64
# district_id     int64
# frequency      object
# date            int64
# dtype: object

# %%
df_accounts.head(2)
# Out:
#    account_id  district_id         frequency    date
# 0         576           55  POPLATEK MESICNE  930101
# 1        3818           74  POPLATEK MESICNE  930101

# %% [markdown]
# *From the documentation, date attribute here is not used*

# %%
df_accounts.drop(['date'], axis=1, inplace=True)

# %% [markdown]
# #### 1.2.4 Typo Data

# %%
for i in df_accounts.select_dtypes(exclude=['number','datetime']):
  unique_data = df_accounts[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |                    |   frequency |
# |:-------------------|------------:|
# | POPLATEK MESICNE   |        4167 |
# | POPLATEK TYDNE     |         240 |
# | POPLATEK PO OBRATU |          93 |

# %% [markdown]
# *rename each value*

# %%
ori_val = ['POPLATEK MESICNE','POPLATEK TYDNE','POPLATEK PO OBRATU']
trf_val = ['MONTHLY ISSUANCE','WEEKLY ISSUANCE','ISSUANCE AFTER TRANSACTION']

df_accounts['frequency'] = df_accounts['frequency'].replace(ori_val, trf_val)

# %% [markdown]
# ## 2. Clients Dataset

# %% [markdown]
# ### 2.1 Data Extraction

# %%
clients_url='https://drive.google.com/file/d/1KzlWr9EqFv87aY-BiK7AaSXUQrtRth8B/view?usp=sharing'
clients_url='https://drive.google.com/uc?id=' + clients_url.split('/')[-2]
df_clients = pd.read_csv(clients_url,sep=';')
df_clients.head()
# Out:
#    client_id  birth_number  district_id
# 0          1        706213           18
# 1          2        450204            1
# 2          3        406009            1
# 3          4        561201            5
# 4          5        605703            5

# %% [markdown]
# ### 2.2 Data Cleaning

# %% [markdown]
# #### 2.2.1 Understanding the Dataset

# %%
df_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5369 entries, 0 to 5368
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   client_id     5369 non-null   int64
#  1   birth_number  5369 non-null   int64
#  2   district_id   5369 non-null   int64
# dtypes: int64(3)
# memory usage: 126.0 KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 2.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_clients.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 2.2.3 Convert Data Type

# %%
df_clients.dtypes
# Out:
# client_id       int64
# birth_number    int64
# district_id     int64
# dtype: object

# %%
df_clients.head()
# Out:
#    client_id  birth_number  district_id
# 0          1        706213           18
# 1          2        450204            1
# 2          3        406009            1
# 3          4        561201            5
# 4          5        605703            5

# %% [markdown]
# ***convert birth number***

# %%
df_clients['birth_number'] = df_clients['birth_number'].astype(str)

# make the new columns using string indexing
df_clients['birth_year'] = df_clients['birth_number'].str[0:2]
df_clients['birth_month'] = df_clients['birth_number'].str[2:4]
df_clients['birth_date'] = df_clients['birth_number'].str[4:6]

# get rid of the extra variable (if you want)
df_clients.drop('birth_number', axis=1, inplace=True)

# %%
df_clients.head(2)
# Out:
#    client_id  district_id birth_year birth_month birth_date
# 0          1           18         70          62         13
# 1          2            1         45          02         04

# %%
# # convert to year
# df_clients['birth_year'] = pd.to_datetime(df_clients['birth_year'], format='%y').dt.year

# %%
# df_clients['birth_year'] = np.where(df_clients['birth_year'] >= 2022, df_clients['birth_year'] - 100 , df_clients['birth_year'])
# df_clients.head(2)

# %%
# check range of birth year
df_clients[['birth_year']].value_counts().sort_index(ascending=False)
# Out:
# birth_year
# 87            1
# 86            1
# 85            3
# 84            1
# 83            3
#              ..
# 15            4
# 14            4
# 13            3
# 12            1
# 11            2
# Length: 77, dtype: int64

# %%
# convert to numeric 
df_clients['birth_month'] = pd.to_numeric(df_clients['birth_month'], errors = 'coerce')
df_clients['birth_year'] = pd.to_numeric(df_clients['birth_year'], errors = 'coerce')
df_clients['birth_date'] = pd.to_numeric(df_clients['birth_date'], errors = 'coerce')

# feature engineering
df_clients['client_gender'] = df_clients['birth_month'].apply(lambda x: 'Women' if x >= 50 else 'Men')
df_clients['client_age_1999'] = 99 - df_clients['birth_year']

# %%
# convert birth month
df_clients['birth_month'] = np.where(df_clients['birth_month'] >= 50, df_clients['birth_month'] - 50 , df_clients['birth_month'])
df_clients.head(2)
# Out:
#    client_id  district_id  birth_year  birth_month  birth_date client_gender  \
# 0          1           18          70           12          13         Women
# 1          2            1          45            2           4           Men
#
#    client_age_1999
# 0               29
# 1               54

# %% [markdown]
# ***check after converting datatype***

# %%
df_clients.dtypes
# Out:
# client_id           int64
# district_id         int64
# birth_year          int64
# birth_month         int64
# birth_date          int64
# client_gender      object
# client_age_1999     int64
# dtype: object

# %% [markdown]
# ## 3. Disposition Dataset

# %% [markdown]
# ### 3.1 Data Extraction

# %%
disp_url='https://drive.google.com/file/d/1Jr0u8YT1K2UYBOmJUiDnRLerLwtbDGlU/view?usp=sharing'
disp_url='https://drive.google.com/uc?id=' + disp_url.split('/')[-2]
df_disp = pd.read_csv(disp_url,sep=';')
df_disp.head()
# Out:
#    disp_id  client_id  account_id       type
# 0        1          1           1      OWNER
# 1        2          2           2      OWNER
# 2        3          3           2  DISPONENT
# 3        4          4           3      OWNER
# 4        5          5           3  DISPONENT

# %% [markdown]
# ### 3.2 Data Cleaning

# %% [markdown]
# #### 3.2.1 Understanding the Dataset

# %%
df_disp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5369 entries, 0 to 5368
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   disp_id     5369 non-null   int64
#  1   client_id   5369 non-null   int64
#  2   account_id  5369 non-null   int64
#  3   type        5369 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 167.9+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 3.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_disp.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 3.2.3 Convert Data Type

# %%
df_disp.dtypes
# Out:
# disp_id        int64
# client_id      int64
# account_id     int64
# type          object
# dtype: object

# %%
df_disp.head(2)
# Out:
#    disp_id  client_id  account_id   type
# 0        1          1           1  OWNER
# 1        2          2           2  OWNER

# %% [markdown]
# *The data types are correct*

# %% [markdown]
# #### 3.2.4 Typo Data

# %%
for i in df_disp.select_dtypes(exclude=['number']):
  unique_data = df_disp[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |           |   type |
# |:----------|-------:|
# | OWNER     |   4500 |
# | DISPONENT |    869 |

# %% [markdown]
# *rename each value*

# %%
df_disp['type'] = df_disp['type'].replace('DISPONENT','USER')

# %% [markdown]
# ## 4. Loans Dataset

# %% [markdown]
# ### 4.1 Data Extraction

# %%
loan_url='https://drive.google.com/file/d/1G93S6iApWPicyFZEfdx0f_SPOTE9p3rW/view?usp=sharing'
loan_url='https://drive.google.com/uc?id=' + loan_url.split('/')[-2]
df_loan = pd.read_csv(loan_url,sep=';')
df_loan.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status
# 0     5314        1787  930705   96396        12    8033.0      B
# 1     5316        1801  930711  165960        36    4610.0      A
# 2     6863        9188  930728  127080        60    2118.0      A
# 3     5325        1843  930803  105804        36    2939.0      A
# 4     7240       11013  930906  274740        60    4579.0      A

# %% [markdown]
# ### 4.2 Data Cleaning

# %% [markdown]
# #### 4.2.1 Understanding the Dataset

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   loan_id     682 non-null    int64
#  1   account_id  682 non-null    int64
#  2   date        682 non-null    int64
#  3   amount      682 non-null    int64
#  4   duration    682 non-null    int64
#  5   payments    682 non-null    float64
#  6   status      682 non-null    object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 37.4+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 4.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_loan.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 4.2.3 Convert Data Type

# %%
df_loan.dtypes
# Out:
# loan_id         int64
# account_id      int64
# date            int64
# amount          int64
# duration        int64
# payments      float64
# status         object
# dtype: object

# %%
df_loan.head(2)
# Out:
#    loan_id  account_id    date  amount  duration  payments status
# 0     5314        1787  930705   96396        12    8033.0      B
# 1     5316        1801  930711  165960        36    4610.0      A

# %% [markdown]
# ***convert to datetime***

# %%
print('type date before transformation is ',type(df_loan['date'][0]))

# convert 
df_loan['date'] = pd.to_datetime(df_loan['date'],  format='%y%m%d')
print('type date after transformation is ',type(df_loan['date'][0]))
# Out:
# type date before transformation is  <class 'numpy.int64'>
# type date after transformation is  <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ***check after converting datatype***

# %%
df_loan.dtypes
# Out:
# loan_id                int64
# account_id             int64
# date          datetime64[ns]
# amount                 int64
# duration               int64
# payments             float64
# status                object
# dtype: object

# %% [markdown]
# #### 4.2.4 Typo Data

# %%
for i in df_loan.select_dtypes(exclude=['number','datetime']):
  unique_data = df_loan[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |    |   status |
# |:---|---------:|
# | C  |      403 |
# | A  |      203 |
# | D  |       45 |
# | B  |       31 |

# %% [markdown]
# *no typo data*

# %% [markdown]
# ## 5. Permanent Orders Dataset

# %% [markdown]
# ### 5.1 Data Extraction

# %%
order_url='https://drive.google.com/file/d/1WbcpVy_4WtpvvzOue2vpoiqlITBJq0Pk/view?usp=sharing'
order_url='https://drive.google.com/uc?id=' + order_url.split('/')[-2]
df_order = pd.read_csv(order_url,sep=';')
df_order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol
# 0     29401           1      YZ    87144583  2452.0     SIPO
# 1     29402           2      ST    89597016  3372.7     UVER
# 2     29403           2      QR    13943797  7266.0     SIPO
# 3     29404           3      WX    83084338  1135.0     SIPO
# 4     29405           3      CD    24485939   327.0

# %% [markdown]
# ### 5.2 Data Cleaning

# %% [markdown]
# #### 5.2.1 Understanding the Dataset

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6471 entries, 0 to 6470
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    6471 non-null   int64
#  1   account_id  6471 non-null   int64
#  2   bank_to     6471 non-null   object
#  3   account_to  6471 non-null   int64
#  4   amount      6471 non-null   float64
#  5   k_symbol    6471 non-null   object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 303.5+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 5.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_order.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 5.2.3 Convert Data Type

# %%
df_order.dtypes
# Out:
# order_id        int64
# account_id      int64
# bank_to        object
# account_to      int64
# amount        float64
# k_symbol       object
# dtype: object

# %%
df_order.head(2)
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol
# 0     29401           1      YZ    87144583  2452.0     SIPO
# 1     29402           2      ST    89597016  3372.7     UVER

# %% [markdown]
# *The data types are correct*

# %% [markdown]
# #### 5.2.4 Typo Data

# %%
for i in df_order.select_dtypes(exclude=['number','datetime']):
  unique_data = df_order[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |    |   bank_to |
# |:---|----------:|
# | QR |       531 |
# | YZ |       521 |
# | AB |       519 |
# | WX |       515 |
# | ST |       511 |
# | KL |       500 |
# | UV |       499 |
# | IJ |       496 |
# | GH |       487 |
# | OP |       485 |
# | EF |       483 |
# | MN |       466 |
# | CD |       458 |
#
#
# |          |   k_symbol |
# |:---------|-----------:|
# | SIPO     |       3502 |
# |          |       1379 |
# | UVER     |        717 |
# | POJISTNE |        532 |
# | LEASING  |        341 |

# %% [markdown]
# *no typo data*

# %% [markdown]
# ***check the empty value in k_symbol column***

# %%
df_order[df_order['k_symbol'] == ' '].head()
# Out:
#     order_id  account_id bank_to  account_to  amount k_symbol
# 4      29405           3      CD    24485939   327.0
# 12     29413           8      IJ    93210345  6712.0
# 28     29430          24      QR    46086388  7641.0
# 31     29433          25      AB    79838293  1110.0
# 36     29440          29      MN    93088209   829.0

# %% [markdown]
# ***percentage of missing values in k_symbol column***

# %%
df_order[df_order['k_symbol'] == ' ']['k_symbol'].count() / len(df_order)
# Out:
# 0.21310462061505178

# %% [markdown]
# *21% of the values are missing, removed attribute due to missing values*

# %%
# drop k_symbol column
df_order.drop(['k_symbol'], axis=1, inplace=True)

# %% [markdown]
# ## 6. Transactions Dataset

# %% [markdown]
# ### 6.1 Data Extraction

# %%
trs_url='https://drive.google.com/file/d/1AkX-4_EEIDZdIi_YVJyzTa-q1t7LbSJZ/view?usp=sharing'
trs_url='https://drive.google.com/uc?id=' + trs_url.split('/')[-2]
df_trs = pd.read_csv(trs_url,sep=';')
df_trs.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  PRIJEM     VKLAD   700.0    700.0      NaN
# 1    171812         576  930101  PRIJEM     VKLAD   900.0    900.0      NaN
# 2    207264         704  930101  PRIJEM     VKLAD  1000.0   1000.0      NaN
# 3   1117247        3818  930101  PRIJEM     VKLAD   600.0    600.0      NaN
# 4    579373        1972  930102  PRIJEM     VKLAD   400.0    400.0      NaN
#
#   bank  account
# 0  NaN      NaN
# 1  NaN      NaN
# 2  NaN      NaN
# 3  NaN      NaN
# 4  NaN      NaN

# %%
df_trx = df_trs.copy()

# %% [markdown]
# ### 6.2 Data Cleaning

# %% [markdown]
# #### 6.2.1 Understanding the Dataset

# %%
df_trx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   trans_id    1056320 non-null  int64
#  1   account_id  1056320 non-null  int64
#  2   date        1056320 non-null  int64
#  3   type        1056320 non-null  object
#  4   operation   873206 non-null   object
#  5   amount      1056320 non-null  float64
#  6   balance     1056320 non-null  float64
#  7   k_symbol    574439 non-null   object
#  8   bank        273508 non-null   object
#  9   account     295389 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 80.6+ MB

# %% [markdown]
# #### 6.2.2 Missing Values

# %% [markdown]
# ***check missing values***

# %%
df_trx.isna().sum()
# Out:
# trans_id           0
# account_id         0
# date               0
# type               0
# operation     183114
# amount             0
# balance            0
# k_symbol      481881
# bank          782812
# account       760931
# dtype: int64

# %% [markdown]
# ***percentage of missing values in each column***

# %%
df_trx.isna().sum() * 100 / len(df_trx)
# Out:
# trans_id       0.000000
# account_id     0.000000
# date           0.000000
# type           0.000000
# operation     17.335088
# amount         0.000000
# balance        0.000000
# k_symbol      45.618847
# bank          74.107467
# account       72.036031
# dtype: float64

# %% [markdown]
# ***check for missing values in each column***

# %% [markdown]
# *after checking from the data source, missing values operation, amount, balance, k_symbol, bank, and account are 'flag record - do not use'*

# %%
# drop missing values in flag record
df_trx.dropna(axis=0, inplace=True)

# %% [markdown]
# ***re-check columns and the number of missing values***

# %%
df_trx.isna().sum()
# Out:
# trans_id      0
# account_id    0
# date          0
# type          0
# operation     0
# amount        0
# balance       0
# k_symbol      0
# bank          0
# account       0
# dtype: int64

# %% [markdown]
# #### 6.2.3 Duplicated Data

# %%
print("Number of duplicated data:", df_trx.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 6.2.4 Convert Data Type

# %%
df_trx.dtypes
# Out:
# trans_id        int64
# account_id      int64
# date            int64
# type           object
# operation      object
# amount        float64
# balance       float64
# k_symbol       object
# bank           object
# account       float64
# dtype: object

# %%
df_trx.head(2)
# Out:
#     trans_id  account_id    date    type      operation  amount  balance  \
# 15    637742        2177  930105  PRIJEM  PREVOD Z UCTU  5123.0   5923.0
# 24    579374        1972  930107  PRIJEM  PREVOD Z UCTU  5298.0   5698.0
#
#    k_symbol bank     account
# 15   DUCHOD   YZ  62457513.0
# 24   DUCHOD   UV  14132887.0

# %% [markdown]
# ***convert to datetime***

# %%
# convert 
df_trx['date'] = pd.to_datetime(df_trx['date'],  format='%y%m%d')

# %% [markdown]
# ***check after converting datatype***

# %%
df_trx.dtypes
# Out:
# trans_id               int64
# account_id             int64
# date          datetime64[ns]
# type                  object
# operation             object
# amount               float64
# balance              float64
# k_symbol              object
# bank                  object
# account              float64
# dtype: object

# %% [markdown]
# #### 6.2.5 Typo Data

# %%
for i in df_trx.select_dtypes(exclude=['number','datetime']):
  unique_data = df_trx[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |        |   type |
# |:-------|-------:|
# | VYDAJ  | 200127 |
# | PRIJEM |  30338 |
#
#
# |                |   operation |
# |:---------------|------------:|
# | PREVOD NA UCET |      200127 |
# | PREVOD Z UCTU  |       30338 |
#
#
# |          |   k_symbol |
# |:---------|-----------:|
# | SIPO     |     115254 |
# |          |      52817 |
# | DUCHOD   |      30338 |
# | POJISTNE |      18477 |
# | UVER     |      13579 |
#
#
# |    |   bank |
# |:---|-------:|
# | QR |  19346 |
# | YZ |  18565 |
# | AB |  18511 |
# | ST |  18312 |
# | EF |  18071 |
# | KL |  18063 |
# | UV |  17718 |
# | OP |  17596 |
# | GH |  17596 |
# | IJ |  17014 |
# | WX |  16790 |
# | MN |  16501 |
# | CD |  16382 |

# %% [markdown]
# *rename each value*

# %%
# type
ori_type = ['VYDAJ','PRIJEM']
trf_type = ['Withdrawal','Credit']

df_trx['type'] = df_trx['type'].replace(ori_type, trf_type)

# operation
ori_operation = ['PREVOD NA UCET','PREVOD Z UCTU']
trf_operation = ['Remittance to Another Bank','Collection from Another Bank']

df_trx['operation'] = df_trx['operation'].replace(ori_operation, trf_operation)

# k_symbol
ori_k_symbol = ['SIPO','DUCHOD','POJISTNE','UVER']
trf_k_symbol = ['Household','Old-age Pension','Insurance Payment','Loan Payment']

df_trx['k_symbol'] = df_trx['k_symbol'].replace(ori_k_symbol, trf_k_symbol)

# %% [markdown]
# *drop empty value due to flag record*

# %%
# drop k_symbol column
df_trx = df_trx[df_trx['k_symbol'] != ' ']

# %% [markdown]
# ## 7. Demographics Dataset

# %% [markdown]
# ### 7.1 Data Extraction

# %%
district_url='https://drive.google.com/file/d/1tzP51lH41tMyHkewc9zC4F9cJ4nyCr_t/view?usp=sharing'
district_url='https://drive.google.com/uc?id=' + district_url.split('/')[-2]
df_district = pd.read_csv(district_url,sep=';')
df_district.head()
# Out:
#    A1           A2               A3       A4  A5  A6  A7  A8  A9    A10  \
# 0   1  Hl.m. Praha           Prague  1204953   0   0   0   1   1  100.0
# 1   2      Benesov  central Bohemia    88884  80  26   6   2   5   46.7
# 2   3       Beroun  central Bohemia    75232  55  26   4   1   5   41.7
# 3   4       Kladno  central Bohemia   149893  63  29   6   2   6   67.4
# 4   5        Kolin  central Bohemia    95616  65  30   4   1   6   51.4
#
#      A11   A12   A13  A14    A15    A16
# 0  12541  0.29  0.43  167  85677  99107
# 1   8507  1.67  1.85  132   2159   2674
# 2   8980  1.95  2.21  111   2824   2813
# 3   9753  4.64  5.05  109   5244   5892
# 4   9307  3.85  4.43  118   2616   3040

# %% [markdown]
# ### 7.2 Data Cleaning

# %% [markdown]
# #### 7.2.1 Understanding the Dataset

# %%
df_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      77 non-null     int64
#  1   A2      77 non-null     object
#  2   A3      77 non-null     object
#  3   A4      77 non-null     int64
#  4   A5      77 non-null     int64
#  5   A6      77 non-null     int64
#  6   A7      77 non-null     int64
#  7   A8      77 non-null     int64
#  8   A9      77 non-null     int64
#  9   A10     77 non-null     float64
#  10  A11     77 non-null     int64
#  11  A12     77 non-null     object
#  12  A13     77 non-null     float64
#  13  A14     77 non-null     int64
#  14  A15     77 non-null     object
#  15  A16     77 non-null     int64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 9.8+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# #### 7.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_district.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 7.2.3 Convert Data Type

# %%
df_district.dtypes
# Out:
# A1       int64
# A2      object
# A3      object
# A4       int64
# A5       int64
# A6       int64
# A7       int64
# A8       int64
# A9       int64
# A10    float64
# A11      int64
# A12     object
# A13    float64
# A14      int64
# A15     object
# A16      int64
# dtype: object

# %%
df_district.head(2)
# Out:
#    A1           A2               A3       A4  A5  A6  A7  A8  A9    A10  \
# 0   1  Hl.m. Praha           Prague  1204953   0   0   0   1   1  100.0
# 1   2      Benesov  central Bohemia    88884  80  26   6   2   5   46.7
#
#      A11   A12   A13  A14    A15    A16
# 0  12541  0.29  0.43  167  85677  99107
# 1   8507  1.67  1.85  132   2159   2674

# %% [markdown]
# ***convert to numeric***

# %% [markdown]
# * A12

# %%
print('type A12 before transformation is ',type(df_district['A12'][0]))

# convert 
df_district['A12'] =  pd.to_numeric(df_district['A12'],errors = 'coerce')
print('type A12 after transformation is ',type(df_district['A12'][0]))
# Out:
# type A12 before transformation is  <class 'str'>
# type A12 after transformation is  <class 'numpy.float64'>

# %%
# recheck missing value 
df_district['A12'].isna().sum()
# Out:
# 1

# %%
df_district[df_district['A12'].isna()]
# Out:
#     A1       A2             A3     A4  A5  A6  A7  A8  A9   A10   A11  A12  \
# 68  69  Jesenik  north Moravia  42821   4  13   5   1   3  48.4  8173  NaN
#
#      A13  A14 A15   A16
# 68  7.01  124   ?  1358

# %% [markdown]
# *drop missing value*

# %%
df_district.dropna(axis=0, inplace=True)

# %% [markdown]
# * A15

# %%
print('type A15 before transformation is ',type(df_district['A15'][0]))

# convert 
df_district['A15'] =  pd.to_numeric(df_district['A15'],errors = 'coerce')
print('type A15 after transformation is ',type(df_district['A15'][0]))
# Out:
# type A15 before transformation is  <class 'str'>
# type A15 after transformation is  <class 'numpy.int64'>

# %%
# recheck missing value 
df_district['A15'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***check after converting datatype***

# %%
df_district.dtypes
# Out:
# A1       int64
# A2      object
# A3      object
# A4       int64
# A5       int64
# A6       int64
# A7       int64
# A8       int64
# A9       int64
# A10    float64
# A11      int64
# A12    float64
# A13    float64
# A14      int64
# A15      int64
# A16      int64
# dtype: object

# %% [markdown]
# #### 7.2.4 Typo Data

# %%
for i in df_district.select_dtypes(exclude=['number']):
  unique_data = df_district[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |                     |   A2 |
# |:--------------------|-----:|
# | Hl.m. Praha         |    1 |
# | Semily              |    1 |
# | Breclav             |    1 |
# | Brno - venkov       |    1 |
# | Brno - mesto        |    1 |
# | Blansko             |    1 |
# | Usti nad Orlici     |    1 |
# | Trutnov             |    1 |
# | Svitavy             |    1 |
# | Rychnov nad Kneznou |    1 |
# | Benesov             |    1 |
# | Pardubice           |    1 |
# | Nachod              |    1 |
# | Jicin               |    1 |
# | Chrudim             |    1 |
# | Hradec Kralove      |    1 |
# | Havlickuv Brod      |    1 |
# | Usti nad Labem      |    1 |
# | Hodonin             |    1 |
# | Jihlava             |    1 |
# | Kromeriz            |    1 |
# | Prostejov           |    1 |
# | Sumperk             |    1 |
# | Prerov              |    1 |
# | Ostrava - mesto     |    1 |
# | Opava               |    1 |
# | Olomouc             |    1 |
# | Novy Jicin          |    1 |
# ...

# %% [markdown]
# *no typo data*

# %% [markdown]
# ## 8. Credit Cards Dataset

# %% [markdown]
# ### 8.1 Data Extraction

# %%
cc_url='https://drive.google.com/file/d/1q0WokWL31CYMEkOWNIQDi14H--fzq_1n/view?usp=sharing'
cc_url='https://drive.google.com/uc?id=' + cc_url.split('/')[-2]
df_cc = pd.read_csv(cc_url,sep=';')
df_cc.head()
# Out:
#    card_id  disp_id     type           issued
# 0     1005     9285  classic  931107 00:00:00
# 1      104      588  classic  940119 00:00:00
# 2      747     4915  classic  940205 00:00:00
# 3       70      439  classic  940208 00:00:00
# 4      577     3687  classic  940215 00:00:00

# %% [markdown]
# ### 8.2 Data Cleaning

# %% [markdown]
# #### 8.2.1 Understanding the Dataset

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   card_id  892 non-null    int64
#  1   disp_id  892 non-null    int64
#  2   type     892 non-null    object
#  3   issued   892 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
# *no missing values*

# %% [markdown]
# *From the documentation, issued attribute here is not used*

# %%
df_cc.drop(['issued'], axis=1, inplace=True)

# %% [markdown]
# #### 8.2.2 Duplicated Data

# %%
print("Number of duplicated data:", df_cc.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# #### 8.2.3 Convert Data Type

# %%
df_cc.dtypes
# Out:
# card_id     int64
# disp_id     int64
# type       object
# dtype: object

# %%
df_cc.head(2)
# Out:
#    card_id  disp_id     type
# 0     1005     9285  classic
# 1      104      588  classic

# %% [markdown]
# *The data types are correct*

# %% [markdown]
# #### 8.2.4 Typo Data

# %%
for i in df_cc.select_dtypes(exclude=['number','datetime']):
  unique_data = df_cc[i].value_counts()
  print(unique_data.to_markdown(), '\n\n')
# Out:
# |         |   type |
# |:--------|-------:|
# | classic |    659 |
# | junior  |    145 |
# | gold    |     88 |

# %% [markdown]
# *no typo data*

# %% [markdown]
# ## 9. Combine the dataset into single dataset

# %% [markdown]
# * combine disp and accounts

# %%
df1 = df_disp.merge(
    df_accounts,
    on = 'account_id',
    how='left'
)

# %%
df1.head(3)
# Out:
#    disp_id  client_id  account_id   type  district_id         frequency
# 0        1          1           1  OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2  OWNER            1  MONTHLY ISSUANCE
# 2        3          3           2   USER            1  MONTHLY ISSUANCE

# %%
# check missing values
df1.isna().sum()
# Out:
# disp_id        0
# client_id      0
# account_id     0
# type           0
# district_id    0
# frequency      0
# dtype: int64

# %% [markdown]
# * combine with clients

# %%
df2 = df1.merge(
    df_clients,
    on='client_id',
    how='left'
)

# %%
df2.head(5)
# Out:
#    disp_id  client_id  account_id   type  district_id_x         frequency  \
# 0        1          1           1  OWNER             18  MONTHLY ISSUANCE
# 1        2          2           2  OWNER              1  MONTHLY ISSUANCE
# 2        3          3           2   USER              1  MONTHLY ISSUANCE
# 3        4          4           3  OWNER              5  MONTHLY ISSUANCE
# 4        5          5           3   USER              5  MONTHLY ISSUANCE
#
#    district_id_y  birth_year  birth_month  birth_date client_gender  \
# 0             18          70           12          13         Women
# 1              1          45            2           4           Men
# 2              1          40           10           9         Women
# 3              5          56           12           1           Men
# 4              5          60            7           3         Women
#
#    client_age_1999
# 0               29
# 1               54
# 2               59
# 3               43
# ...

# %%
# check missing values
df2.isna().sum()
# Out:
# disp_id            0
# client_id          0
# account_id         0
# type               0
# district_id_x      0
# frequency          0
# district_id_y      0
# birth_year         0
# birth_month        0
# birth_date         0
# client_gender      0
# client_age_1999    0
# dtype: int64

# %%
# drop district_id_y column having the same values with district_id_x
df2.drop(['district_id_y'], axis=1, inplace=True)
df2.rename({'district_id_x': 'district_id'}, axis=1, inplace=True)

# %% [markdown]
# * combine with card

# %%
df3 = df2.merge(
    df_cc,
    on='disp_id',
    how='left',
    suffixes=('_account', '_card')
)

# %%
df3.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2        OWNER            1  MONTHLY ISSUANCE
# 2        3          3           2         USER            1  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          45            2           4           Men               54
# 2          40           10           9         Women               59
#
#    card_id type_card
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN

# %%
# check missing values
df3.isna().sum()
# Out:
# disp_id               0
# client_id             0
# account_id            0
# type_account          0
# district_id           0
# frequency             0
# birth_year            0
# birth_month           0
# birth_date            0
# client_gender         0
# client_age_1999       0
# card_id            4477
# type_card          4477
# dtype: int64

# %% [markdown]
# *will be handled later*

# %% [markdown]
# * combine with district

# %%
df4 = df3.merge(
    df_district,
    left_on='district_id',
    right_on='A1',
    how='left'
)

# %%
df4.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2        OWNER            1  MONTHLY ISSUANCE
# 2        3          3           2         USER            1  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          45            2           4           Men               54
# 2          40           10           9         Women               59
#
#    card_id type_card    A1           A2             A3         A4    A5    A6  \
# 0      NaN       NaN  18.0        Pisek  south Bohemia    70699.0  60.0  13.0
# 1      NaN       NaN   1.0  Hl.m. Praha         Prague  1204953.0   0.0   0.0
# 2      NaN       NaN   1.0  Hl.m. Praha         Prague  1204953.0   0.0   0.0
#
# ...

# %%
# check missing values
df4.isna().sum()
# Out:
# disp_id               0
# client_id             0
# account_id            0
# type_account          0
# district_id           0
# frequency             0
# birth_year            0
# birth_month           0
# birth_date            0
# client_gender         0
# client_age_1999       0
# card_id            4477
# type_card          4477
# A1                   57
# A2                   57
# A3                   57
# A4                   57
# A5                   57
# A6                   57
# A7                   57
# A8                   57
# A9                   57
# A10                  57
# A11                  57
# A12                  57
# A13                  57
# A14                  57
# A15                  57
# A16                  57
# dtype: int64

# %% [markdown]
# *will be handled later*

# %%
# rename column 
df4.rename(columns={
    'A1': 'District Identifier',
    'A2': 'District Name',
    'A3': 'Region Name',
    'A4': 'Number of Inhabitants',
    'A5': 'Number of municipalities with <499 inhabitants',
    'A6': 'Number of municipalities with 500-1499 inhabitants',
    'A7': 'Number of municipalities with 2000-9999 inhabitants',
    'A8': 'Number of municipalities with >10000 inhabitants',
    'A9': 'Number of cities',
    'A10': 'Ratio of urban inhabitants',
    'A11': 'Average salary',
    'A12': '1995 unemployment rate',
    'A13': '1996 unemployment rate',
    'A14': 'Entrepreneurs per 1000 inhabitants',
    'A15': 'Number of crimes committed in 1995',
    'A16': 'Number of crimes committed in 1996'
}, inplace=True)

# %%
df4.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2        OWNER            1  MONTHLY ISSUANCE
# 2        3          3           2         USER            1  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          45            2           4           Men               54
# 2          40           10           9         Women               59
#
#    card_id type_card  District Identifier District Name    Region Name  \
# 0      NaN       NaN                 18.0         Pisek  south Bohemia
# 1      NaN       NaN                  1.0   Hl.m. Praha         Prague
# 2      NaN       NaN                  1.0   Hl.m. Praha         Prague
#
#    Number of Inhabitants  Number of municipalities with <499 inhabitants  \
# ...

# %% [markdown]
# * combine with loan

# %%
df5 = df4.merge(
    df_loan,
    on='account_id',
    how='left'
)

# %%
df5.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2        OWNER            1  MONTHLY ISSUANCE
# 2        3          3           2         USER            1  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          45            2           4           Men               54
# 2          40           10           9         Women               59
#
#    card_id type_card  District Identifier District Name    Region Name  \
# 0      NaN       NaN                 18.0         Pisek  south Bohemia
# 1      NaN       NaN                  1.0   Hl.m. Praha         Prague
# 2      NaN       NaN                  1.0   Hl.m. Praha         Prague
#
#    Number of Inhabitants  Number of municipalities with <499 inhabitants  \
# ...

# %%
# check missing values
df5.isna().sum()
# Out:
# disp_id                                                   0
# client_id                                                 0
# account_id                                                0
# type_account                                              0
# district_id                                               0
# frequency                                                 0
# birth_year                                                0
# birth_month                                               0
# birth_date                                                0
# client_gender                                             0
# client_age_1999                                           0
# card_id                                                4477
# type_card                                              4477
# District Identifier                                      57
# District Name                                            57
# Region Name                                              57
# ...

# %% [markdown]
# *will be handled later*

# %% [markdown]
# * combine with order

# %%
df6 = df5.merge(
    df_order,
    on='account_id',
    how='left',
    suffixes=('_loan', '_order')
)

# %%
df6.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        2          2           2        OWNER            1  MONTHLY ISSUANCE
# 2        2          2           2        OWNER            1  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          45            2           4           Men               54
# 2          45            2           4           Men               54
#
#    card_id type_card  District Identifier District Name    Region Name  \
# 0      NaN       NaN                 18.0         Pisek  south Bohemia
# 1      NaN       NaN                  1.0   Hl.m. Praha         Prague
# 2      NaN       NaN                  1.0   Hl.m. Praha         Prague
#
#    Number of Inhabitants  Number of municipalities with <499 inhabitants  \
# ...

# %%
# check missing values
df6.isna().sum()
# Out:
# disp_id                                                   0
# client_id                                                 0
# account_id                                                0
# type_account                                              0
# district_id                                               0
# frequency                                                 0
# birth_year                                                0
# birth_month                                               0
# birth_date                                                0
# client_gender                                             0
# client_age_1999                                           0
# card_id                                                7232
# type_card                                              7232
# District Identifier                                      86
# District Name                                            86
# Region Name                                              86
# ...

# %% [markdown]
# *will be handled later*

# %% [markdown]
# * combine with transaction

# %%
df7 = df6.merge(
    df_trx,
    on='account_id',
    how='left',
    suffixes=('_loan', '_transaction')
)

# %%
df7.head(3)
# Out:
#    disp_id  client_id  account_id type_account  district_id         frequency  \
# 0        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 1        1          1           1        OWNER           18  MONTHLY ISSUANCE
# 2        1          1           1        OWNER           18  MONTHLY ISSUANCE
#
#    birth_year  birth_month  birth_date client_gender  client_age_1999  \
# 0          70           12          13         Women               29
# 1          70           12          13         Women               29
# 2          70           12          13         Women               29
#
#    card_id type_card  District Identifier District Name    Region Name  \
# 0      NaN       NaN                 18.0         Pisek  south Bohemia
# 1      NaN       NaN                 18.0         Pisek  south Bohemia
# 2      NaN       NaN                 18.0         Pisek  south Bohemia
#
#    Number of Inhabitants  Number of municipalities with <499 inhabitants  \
# ...

# %%
# check missing values
df7.isna().sum()
# Out:
# disp_id                                                     0
# client_id                                                   0
# account_id                                                  0
# type_account                                                0
# district_id                                                 0
# frequency                                                   0
# birth_year                                                  0
# birth_month                                                 0
# birth_date                                                  0
# client_gender                                               0
# client_age_1999                                             0
# card_id                                                359219
# type_card                                              359219
# District Identifier                                      2629
# District Name                                            2629
# ...

# %% [markdown]
# *will be handled later*

# %%
# df7.to_excel ("merge_data.xlsx", index = False, header=True)

# %% [markdown]
# ## 10. Data Cleaning After Merging

# %%
df_mg = df7.copy()

# %% [markdown]
# ***Check Missing Values***

# %%
df_mg.isna().sum()
# Out:
# disp_id                                                     0
# client_id                                                   0
# account_id                                                  0
# type_account                                                0
# district_id                                                 0
# frequency                                                   0
# birth_year                                                  0
# birth_month                                                 0
# birth_date                                                  0
# client_gender                                               0
# client_age_1999                                             0
# card_id                                                359219
# type_card                                              359219
# District Identifier                                      2629
# District Name                                            2629
# ...

# %% [markdown]
# ***percentage of missing values in each column***

# %%
df_mg.isna().sum() * 100 / len(df_mg)
# Out:
# disp_id                                                 0.000000
# client_id                                               0.000000
# account_id                                              0.000000
# type_account                                            0.000000
# district_id                                             0.000000
# frequency                                               0.000000
# birth_year                                              0.000000
# birth_month                                             0.000000
# birth_date                                              0.000000
# client_gender                                           0.000000
# client_age_1999                                         0.000000
# card_id                                                85.125810
# type_card                                              85.125810
# District Identifier                                     0.623006
# ...

# %% [markdown]
# ***check for missing values in each column***

# %% [markdown]
# * *card id*

# %%
# compute corr
pd.DataFrame(df_mg.corr()['card_id'].sort_values(ascending=False))
# Out:
#                                                      card_id
# card_id                                             1.000000
# loan_id                                             0.972497
# disp_id                                             0.962602
# account_id                                          0.961757
# order_id                                            0.960947
# client_id                                           0.959053
# trans_id                                            0.957599
# amount_loan                                         0.233226
# duration                                            0.175025
# birth_year                                          0.144085
# amount_order                                        0.117642
# amount                                              0.100205
# Entrepreneurs per 1000 inhabitants                  0.083068
# Average salary                                      0.063518
# ...

# %% [markdown]
# *There seems to be any relationship between 'card_id' with 'loan_id', 'disp_id', 'order_id', 'account_id', 'trans_id' and 'client_id' column. These columns will be deleted, except 'account_id', because we assume 'account_id' is sufficient to represent this data*

# %%
df_mg.drop(['card_id','loan_id','disp_id','order_id','client_id','trans_id'], axis=1, inplace=True)

# %% [markdown]
# * *type card*

# %%
df_mg['type_card'].value_counts()
# Out:
# classic    47025
# junior      9111
# gold        6631
# Name: type_card, dtype: int64

# %% [markdown]
# *Each record describes a credit card issued to an account, so we assume missing data as 'non cc holder'*

# %%
df_mg['type_card'].fillna('non cc holder', inplace=True)

# %%
# recheck the missing values
df_mg.isna().sum() * 100 / len(df_mg)
# Out:
# account_id                                              0.000000
# type_account                                            0.000000
# district_id                                             0.000000
# frequency                                               0.000000
# birth_year                                              0.000000
# birth_month                                             0.000000
# birth_date                                              0.000000
# client_gender                                           0.000000
# client_age_1999                                         0.000000
# type_card                                               0.000000
# District Identifier                                     0.623006
# District Name                                           0.623006
# Region Name                                             0.623006
# Number of Inhabitants                                   0.623006
# ...

# %% [markdown]
# * *date_loan*

# %% [markdown]
# *74% of the values are missing, removed attribute due to missing values*

# %%
df_mg.drop(['date_loan'], axis=1, inplace=True)

# %% [markdown]
# * *amount loan, duration, payments, status*

# %% [markdown]
# *Each record describes a loan granted for a given account, so we assume missing data as 0 and 'None'*

# %%
df_mg['amount_loan'].fillna(0, inplace=True)

# %%
df_mg['duration'].fillna(0, inplace=True)

# %%
df_mg['payments'].fillna(0, inplace=True)

# %%
df_mg['status'].fillna('N', inplace=True)

# %%
# recheck the missing values
df_mg.isna().sum() * 100 / len(df_mg)
# Out:
# account_id                                             0.000000
# type_account                                           0.000000
# district_id                                            0.000000
# frequency                                              0.000000
# birth_year                                             0.000000
# birth_month                                            0.000000
# birth_date                                             0.000000
# client_gender                                          0.000000
# client_age_1999                                        0.000000
# type_card                                              0.000000
# District Identifier                                    0.623006
# District Name                                          0.623006
# Region Name                                            0.623006
# Number of Inhabitants                                  0.623006
# Number of municipalities with <499 inhabitants         0.623006
# ...

# %% [markdown]
# ***percentage of rows with missing values***

# %%
df_mg.isnull().any(axis=1).sum() * 100 /len(df_mg)
# Out:
# 0.9616432772651226

# %% [markdown]
# ***drop columns?***

# %% [markdown]
# *The missing value in each column has a very small percentage, **< 1%**. Therefore, **column removal is not needed because the percentage of missing values is quite small**.*

# %% [markdown]
# ***drop rows***

# %% [markdown]
# *So, for this case, I decide to delete the records containing empty values because the percentage of rows with empty values is low **(1%)** compared to the whole dataset, so we still have  enough samples in the data set.*

# %%
df_mg.dropna(axis=0, inplace=True)

# %% [markdown]
# ***re-check the number of missing values***

# %%
df_mg.isna().sum()
# Out:
# account_id                                             0
# type_account                                           0
# district_id                                            0
# frequency                                              0
# birth_year                                             0
# birth_month                                            0
# birth_date                                             0
# client_gender                                          0
# client_age_1999                                        0
# type_card                                              0
# District Identifier                                    0
# District Name                                          0
# Region Name                                            0
# Number of Inhabitants                                  0
# Number of municipalities with <499 inhabitants         0
# Number of municipalities with 500-1499 inhabitants     0
# ...

# %% [markdown]
# *Missing values already been handled, ​​no longer exist in the data.*

# %% [markdown]
# ***Duplicated Data***

# %%
print("Number of duplicated data:", df_mg.duplicated().sum())
# Out:
# Number of duplicated data: 0

# %% [markdown]
# *No duplicate values ​​or rows in data*

# %% [markdown]
# ***Numerical Data***

# %%
numerical = df_mg.select_dtypes(include=['number'])
numerical.head(3)
# Out:
#    account_id  district_id  birth_year  birth_month  birth_date  \
# 0           1           18          70           12          13
# 1           1           18          70           12          13
# 2           1           18          70           12          13
#
#    client_age_1999  District Identifier  Number of Inhabitants  \
# 0               29                 18.0                70699.0
# 1               29                 18.0                70699.0
# 2               29                 18.0                70699.0
#
#    Number of municipalities with <499 inhabitants  \
# 0                                            60.0
# 1                                            60.0
# 2                                            60.0
#
#    Number of municipalities with 500-1499 inhabitants  \
# 0                                               13.0
# 1                                               13.0
# 2                                               13.0
#
# ...

# %% [markdown]
# ***Categorical Data***

# %%
categorical = df_mg.select_dtypes(exclude=['number'])
categorical.head(3)
# Out:
#   type_account         frequency client_gender      type_card District Name  \
# 0        OWNER  MONTHLY ISSUANCE         Women  non cc holder         Pisek
# 1        OWNER  MONTHLY ISSUANCE         Women  non cc holder         Pisek
# 2        OWNER  MONTHLY ISSUANCE         Women  non cc holder         Pisek
#
#      Region Name status bank_to date_transaction        type  \
# 0  south Bohemia      N      YZ       1995-09-05  Withdrawal
# 1  south Bohemia      N      YZ       1995-10-05  Withdrawal
# 2  south Bohemia      N      YZ       1995-11-05  Withdrawal
#
#                     operation   k_symbol bank
# 0  Remittance to Another Bank  Household   YZ
# 1  Remittance to Another Bank  Household   YZ
# 2  Remittance to Another Bank  Household   YZ

# %% [markdown]
# ## 11. Exploratory Data Analysis

# %% [markdown]
# ### 11.1 Descriptive Statistics

# %%
from scipy import stats


def describe(df, statis):
    d = df.describe()
    
    if 'mode' in statis:
        statis.remove('mode')
        d = d.append(df.agg(statis))
        d = d.append(df.agg(lambda x: stats.mode(x)[0]))
        d = d.rename(index={0:'mode'})
    else: 
        d = d.append(df.agg(statis))
    return d


ds = describe(numerical, ['mode','var','skew','kurt'])

# add range 
ds.loc['range'] = ds.loc['max'] - ds.loc['min']

# coefficient of variation (std / mean) 
ds.loc['coeff of var'] = ds.loc['std'] / ds.loc['mean']

ds
# Out:
#                 account_id    district_id     birth_year    birth_month  \
# count         4.179280e+05  417928.000000  417928.000000  417928.000000
# mean          3.060444e+03      36.867927      51.639658       6.537786
# std           2.623526e+03      25.492539      17.427070       3.408003
# min           1.000000e+00       1.000000      11.000000       1.000000
# 25%           1.270000e+03      12.000000      39.000000       4.000000
# 50%           2.472000e+03      37.000000      52.000000       7.000000
# 75%           3.709000e+03      60.000000      67.000000       9.000000
# max           1.136200e+04      77.000000      87.000000      12.000000
# var           6.882886e+06     649.869549     303.702763      11.614486
# skew          1.430899e+00      -0.006595      -0.153082      -0.051053
# kurt          1.452444e+00      -1.397490      -1.007659      -1.180096
# mode          7.133000e+03       1.000000      40.000000       9.000000
# ...

# %%
categorical.describe()
# Out:
#        type_account         frequency client_gender      type_card  \
# count        417928            417928        417928         417928
# unique            2                 3             2              4
# top           OWNER  MONTHLY ISSUANCE         Women  non cc holder
# freq         340821            386640        211550         355938
# first           NaN               NaN           NaN            NaN
# last            NaN               NaN           NaN            NaN
#
#        District Name    Region Name  status bank_to     date_transaction  \
# count         417928         417928  417928  417928               417928
# unique            76              8       5      13                  715
# top      Hl.m. Praha  north Moravia       N      AB  1998-07-12 00:00:00
# freq           55343          74115  306406   34580                 2356
# first            NaN            NaN     NaN     NaN  1993-01-05 00:00:00
# ...

# %% [markdown]
# ### 11.2 Univariate Analysis

# %% [markdown]
# #### 11.2.1 Boxplot

# %%
len(numerical.columns)
# Out:
# 28

# %%
plt.figure(figsize=(15,17))
for i in range(0, len(numerical.columns)):
    ax = plt.subplot(10,3,i+1)
    sns.boxplot(numerical[numerical.columns[i]], color='lightblue')
    plt.tight_layout()

# %% [markdown]
# * *The boxplot graphs above show that 'account_id','Number of Inhabitants','Number of municipalities with <499 inhabitants','Number of municipalities with 500-1499 inhabitants','Number of municipalities with 2000-9999 inhabitants','Number of municipalities with >10000 inhabitants','Average salary','1996 unemployment rate','Number of crimes committed in 1995','Number of crimes committed in 1996','amount_loan','duration','payments','amount_order','amount','balance' have a distribution affected by outliers shown on the graph. The outliers are piled up at the right or left end*
# * *'Number of cities','birth_month','Ratio of urban inhabitants','Entrepreneurs per 1000 inhabitants' has an asymmetric distribution shown by median line that is not in the middle of interquartile range. However, there are no outliers on the graph. It may be affected by the number of modes that is more than 1 and imbalanced. The number of modes indicates there are different groups*
# * *'birth_year','client_age_1999','birth_date','District Identifier','1995 unemployment rate' tend to have a normal distribution shown by median line in the midle of IQR*

# %% [markdown]
# #### 11.2.2 Displot

# %%
plt.figure(figsize=(20,27))
for i in range(0, len(numerical.columns)):
    ax = plt.subplot(10,3,i+1)
    sns.distplot(numerical[numerical.columns[i]], color='blue')
    plt.tight_layout()

# %% [markdown]
# ### 11.3 Multivariate Analysis

# %% [markdown]
# #### 11.3.1 Correlation Heatmap

# %%
# compute corr
df_mg.select_dtypes(include=['number']).corr(method = "pearson");

# %%
# compute correlation 
corr = df_mg.select_dtypes(include=['number']).corr(method = "pearson")

# mask for the upper triangle
mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# set figure size
f, ax = plt.subplots(figsize = (50,50))

# set colormap
cmap = sns.diverging_palette(220, 10, as_cmap = True)

sns.heatmap(corr, mask = mask, cmap = cmap, 
           vmin = -1, vmax = 1, center = 0,

            linewidths = .5, cbar_kws = {"shrink": .5}, annot = True);

# %% [markdown]
# *drop redundant features*

# %%
df_mg.drop(['district_id','birth_year','birth_month','birth_date','Number of Inhabitants','Number of municipalities with 500-1499 inhabitants','Ratio of urban inhabitants','Number of crimes committed in 1995','Number of crimes committed in 1996','1995 unemployment rate','Entrepreneurs per 1000 inhabitants'], axis=1, inplace=True)

# %%
df_mg.head(3)
# Out:
#    account_id type_account         frequency client_gender  client_age_1999  \
# 0           1        OWNER  MONTHLY ISSUANCE         Women               29
# 1           1        OWNER  MONTHLY ISSUANCE         Women               29
# 2           1        OWNER  MONTHLY ISSUANCE         Women               29
#
#        type_card  District Identifier District Name    Region Name  \
# 0  non cc holder                 18.0         Pisek  south Bohemia
# 1  non cc holder                 18.0         Pisek  south Bohemia
# 2  non cc holder                 18.0         Pisek  south Bohemia
#
#    Number of municipalities with <499 inhabitants  \
# 0                                            60.0
# 1                                            60.0
# 2                                            60.0
#
#    Number of municipalities with 2000-9999 inhabitants  \
# 0                                                2.0
# 1                                                2.0
# ...

# %% [markdown]
# ## 12. Customer Segementation

# %% [markdown]
# ### 12.1 Agglomerative Clustering

# %% [markdown]
# #### 12.1.1 Data Preprocessing

# %%
customers = df_mg.copy().sample(frac = 0.05)

# %%
customers.head(2)
# Out:
#        account_id type_account         frequency client_gender  \
# 86558        1019        OWNER  MONTHLY ISSUANCE         Women
# 49781         543        OWNER  MONTHLY ISSUANCE         Women
#
#        client_age_1999      type_card  District Identifier    District Name  \
# 86558               44        classic                 52.0  Usti nad Orlici
# 49781               57  non cc holder                 64.0             Zlin
#
#          Region Name  Number of municipalities with <499 inhabitants  \
# 86558   east Bohemia                                            59.0
# 49781  south Moravia                                            29.0
#
#        Number of municipalities with 2000-9999 inhabitants  \
# 86558                                                8.0
# 49781                                               10.0
#
#        Number of municipalities with >10000 inhabitants  Number of cities  \
# 86558                                               3.0              10.0
# ...

# %%
customers[(customers['Region Name']=='south Moravia') & (customers['District Name'].isin(['Trebic','Blansko']))].head()
# Out:
#         account_id type_account         frequency client_gender  \
# 120702        1405        OWNER  MONTHLY ISSUANCE         Women
# 49174          541        OWNER  MONTHLY ISSUANCE           Men
# 162407        1872        OWNER  MONTHLY ISSUANCE         Women
# 58123          655        OWNER  MONTHLY ISSUANCE           Men
# 103133        1241        OWNER  MONTHLY ISSUANCE         Women
#
#         client_age_1999      type_card  District Identifier District Name  \
# 120702               26  non cc holder                 53.0       Blansko
# 49174                61        classic                 61.0        Trebic
# 162407               39  non cc holder                 61.0        Trebic
# 58123                21         junior                 53.0       Blansko
# 103133               51  non cc holder                 53.0       Blansko
#
#           Region Name  Number of municipalities with <499 inhabitants  \
# ...

# %%
# remove irrelevant features1996 unemployment rate
customers.drop(['date_transaction','bank_to','account_id','account_to','account','District Identifier','District Name','Number of municipalities with <499 inhabitants','Number of municipalities with 2000-9999 inhabitants','Number of municipalities with >10000 inhabitants','Number of cities','1996 unemployment rate'], axis=1, inplace=True)

# %% [markdown]
# ##### a. Feature Encoding

# %%
# check categorical columns
customers.select_dtypes(exclude=['number']).head(1)
# Out:
#       type_account         frequency client_gender type_card   Region Name  \
# 86558        OWNER  MONTHLY ISSUANCE         Women   classic  east Bohemia
#
#       status        type                   operation           k_symbol bank
# 86558      N  Withdrawal  Remittance to Another Bank  Insurance Payment   ST

# %%
customers['bank'].value_counts()
# Out:
# EF    356
# QR    352
# KL    347
# UV    341
# ST    335
# CD    327
# YZ    321
# AB    315
# GH    314
# OP    302
# IJ    301
# WX    295
# MN    273
# Name: bank, dtype: int64

# %%
customers_std = customers.copy()

# %%
# One-hot Encoding
def onehot_encode(data, column):
    dummies = pd.get_dummies(data[column], prefix=column)
    data = pd.concat([data, dummies], axis=1)
    data = data.drop(column, axis=1)
    return data

for column in ['frequency','Region Name','k_symbol','bank']:
        customers_std = onehot_encode(customers_std, column=column)

# %%
# Label Encoding
for column in ['type_account','client_gender','type_card','status','type','operation']:
        customers_std[column] = customers_std[column].astype('category').cat.codes

customers_std.head(2)
# Out:
#         type_account  client_gender  client_age_1999  type_card  \
# 124660             0              1               20          3
# 369329             0              1               21          2
#
#         Average salary  amount_loan  duration  payments  status  amount_order  \
# 124660          8441.0          0.0       0.0       0.0       4         668.0
# 369329         12541.0     390660.0      60.0    6511.0       2       10755.0
#
#         type  operation  amount  balance  \
# 124660     1          1  1075.0  24963.1
# 369329     1          1  6510.7  36926.4
#
#         frequency_ISSUANCE AFTER TRANSACTION  frequency_MONTHLY ISSUANCE  \
# 124660                                     0                           1
# 369329                                     0                           1
#
#         frequency_WEEKLY ISSUANCE  Region Name_Prague  \
# 124660                          0                   0
# 369329                          0                   1
#
# ...

# %% [markdown]
# ##### b. Normalisation/Standardisation/Robustscaler

# %%
# check numerical columns
customers.select_dtypes(include=['number']).head(1)
# Out:
#        client_age_1999  Average salary  amount_loan  duration  payments  \
# 86558               44          8363.0          0.0       0.0       0.0
#
#        amount_order  amount  balance
# 86558         629.0   629.0  26199.5

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler

# %%
# Using standardisation for normal distribution assumption of data 

std_columns = ['client_age_1999','type_account','client_gender','type_card','status','type','operation']

for i in std_columns:
    customers_std[i] = StandardScaler().fit_transform(customers_std[i].values.reshape(len(customers_std),1))

# %%
# Using robustscaler for handle outliers 

otlr_columns = ['Average salary','amount_loan','duration','payments','amount_order','amount','balance']

for i in otlr_columns:
    customers_std[i] = RobustScaler(quantile_range = (25.0, 75.0)).fit_transform(customers_std[i].values.reshape(len(customers_std),1))

# %%
# Using normalisation for distribution that is non normal assumption 

norm_columns = ['Average salary','amount_loan','duration','payments','amount_order','amount','balance']

for i in norm_columns:
    customers_std[i] = MinMaxScaler().fit_transform(customers_std[i].values.reshape(len(customers_std),1))

# %%
customers_std.head(3)
# Out:
#         type_account  client_gender  client_age_1999  type_card  \
# 124660     -0.478662       1.005038        -1.580831   0.403966
# 369329     -0.478662       1.005038        -1.523503  -0.629187
# 230236     -0.478662       1.005038        -1.122208   0.403966
#
#         Average salary  amount_loan  duration  payments    status  \
# 124660        0.074701     0.000000       0.0  0.000000  0.562861
# 369329        1.000000     0.661217       1.0  0.657013 -0.893157
# 230236        0.089596     0.000000       0.0  0.000000  0.562861
#
#         amount_order      type  operation    amount   balance  \
# 124660      0.044822  0.349543   0.349543  0.072519  0.225267
# 369329      0.722666  0.349543   0.349543  0.439548  0.313072
# 230236      0.043949  0.349543   0.349543  0.011884  0.220144
#
#         frequency_ISSUANCE AFTER TRANSACTION  frequency_MONTHLY ISSUANCE  \
# 124660                                     0                           1
# ...

# %% [markdown]
# #### 12.1.2 Determine Cluster Number

# %%
from sklearn.cluster import AgglomerativeClustering # For HAC clustering
import scipy.cluster.hierarchy as sch # For HAC Denddrogram

# %%
# Select attributes
X = customers_std

# Create a figure
plt.figure(figsize=(16,9), dpi=300)

# Create linkage
Z = sch.linkage(X, method='ward', optimal_ordering=True) 

# Draw a dendrogram
sch.dendrogram(Z, leaf_rotation=90, leaf_font_size=10, 
               color_threshold=50, above_threshold_color='black')
 
# Add horizontal line
plt.axhline(y=50, c='grey', lw=1, linestyle='dashed')

# Show the plot
plt.show()

# %% [markdown]
# #### 12.1.3 Modelling

# %%
model = AgglomerativeClustering(n_clusters=6, affinity='euclidean')
clust = model.fit(X)

# %%
customers_std['clusters'] = clust.labels_
customers['clusters'] = clust.labels_

# %%
customers.head(3)
# Out:
#        type_account         frequency client_gender  client_age_1999  \
# 86558         OWNER  MONTHLY ISSUANCE         Women               44
# 49781         OWNER  MONTHLY ISSUANCE         Women               57
# 137102        OWNER  MONTHLY ISSUANCE         Women               42
#
#             type_card    Region Name  Average salary  amount_loan  duration  \
# 86558         classic   east Bohemia          8363.0          0.0       0.0
# 49781   non cc holder  south Moravia          9624.0          0.0       0.0
# 137102  non cc holder         Prague         12541.0      78936.0      12.0
#
#         payments status  amount_order        type                   operation  \
# 86558        0.0      N         629.0  Withdrawal  Remittance to Another Bank
# 49781        0.0      N        1086.0  Withdrawal  Remittance to Another Bank
# 137102    6578.0      A        2359.0  Withdrawal  Remittance to Another Bank
#
#         amount  balance           k_symbol bank  clusters
# ...

# %%
# from google.colab import files
# customers.to_excel ("agglomerative cc analysis.xlsx", index = False, header=True) 
# files.download('agglomerative cc analysis.xlsx')

# %% [markdown]
# #### 12.1.4 Interpret The Segment

# %%
customers.groupby(['clusters'])['client_age_1999','Average salary','amount_loan','duration','payments'].agg(['count','mean']).T
# Out:
# clusters                          0              1             2            3  \
# client_age_1999 count    675.000000     738.000000    536.000000   425.000000
#                 mean      44.503704      41.230352     43.119403    71.912941
# Average salary  count    675.000000     738.000000    536.000000   425.000000
#                 mean    9641.693333    9627.806233   9450.048507  9445.611765
# amount_loan     count    675.000000     738.000000    536.000000   425.000000
#                 mean   48886.524444  147298.227642  37630.656716     0.000000
# duration        count    675.000000     738.000000    536.000000   425.000000
#                 mean      10.933333      36.878049     10.791045     0.000000
# payments        count    675.000000     738.000000    536.000000   425.000000
#                 mean    1408.881481    4024.371274   1160.930970     0.000000
#
# clusters                         4            5
# client_age_1999 count   956.000000   849.000000
# ...

# %%
customers.groupby(['clusters','type_account'])['clusters'].agg(['count'])
# Out:
#                        count
# clusters type_account
# 0        USER            675
# 1        OWNER           738
# 2        OWNER           536
# 3        OWNER           320
#          USER            105
# 4        OWNER           956
# 5        OWNER           849

# %%
customers.groupby(['clusters','client_gender'])['clusters'].agg(['count'])
# Out:
#                         count
# clusters client_gender
# 0        Men              335
#          Women            340
# 1        Men              371
#          Women            367
# 2        Men              301
#          Women            235
# 3        Men              208
#          Women            217
# 4        Women            956
# 5        Men              849

# %%
customers.groupby(['clusters','type_card'])['clusters'].agg(['count'])
# Out:
#                         count
# clusters type_card
# 0        non cc holder    675
# 1        junior            36
#          non cc holder    702
# 2        classic          466
#          gold              69
#          junior             1
# 3        classic            1
#          gold               1
#          non cc holder    423
# 4        gold               4
#          junior            27
#          non cc holder    925
# 5        gold               2
#          junior            22
#          non cc holder    825

# %%
customers.groupby(['clusters','status'])['clusters'].agg(['count'])
# Out:
#                  count
# clusters status
# 0        A         101
#          C         109
#          N         465
# 1        A         286
#          B          42
#          C         376
#          D          34
# 2        A          82
#          B           2
#          C          82
#          D           2
#          N         368
# 3        N         425
# 4        D           1
#          N         955
# 5        D           1
#          N         848

# %%
customers.groupby(['clusters','type'])['clusters'].agg(['count'])
# Out:
#                      count
# clusters type
# 0        Withdrawal    675
# 1        Withdrawal    738
# 2        Withdrawal    536
# 3        Credit        425
# 4        Withdrawal    956
# 5        Withdrawal    849

# %%
customers.groupby(['clusters','operation'])['clusters'].agg(['count'])
# Out:
#                                        count
# clusters operation
# 0        Remittance to Another Bank      675
# 1        Remittance to Another Bank      738
# 2        Remittance to Another Bank      536
# 3        Collection from Another Bank    425
# 4        Remittance to Another Bank      956
# 5        Remittance to Another Bank      849

# %%
customers.groupby(['clusters','k_symbol'])['clusters'].agg(['count'])
# Out:
#                             count
# clusters k_symbol
# 0        Household            470
#          Insurance Payment    137
#          Loan Payment          68
# 1        Household            334
#          Insurance Payment    151
#          Loan Payment         253
# 2        Household            371
#          Insurance Payment    107
#          Loan Payment          58
# 3        Old-age Pension      425
# 4        Household            713
#          Insurance Payment    243
# 5        Household            657
#          Insurance Payment    192

# %%
# Create the dataframe
df_normalized = customers_std[['client_age_1999','Average salary','amount_loan','duration','payments']]
df_normalized['ID'] = customers.index
df_normalized['Cluster'] = clust.labels_

# Melt The Data
df_nor_melt = pd.melt(df_normalized.reset_index(),
                      id_vars=['ID', 'Cluster'],
                      value_vars=['client_age_1999','Average salary','amount_loan','duration','payments'],
                      var_name='Attribute',
                      value_name='Value')
df_nor_melt.head()

# Visualize it
plt.figure(figsize=(12,8))
sns.lineplot('Attribute', 'Value', hue='Cluster', palette='dark', data=df_nor_melt)
plt.show()

# %% [markdown]
# - cluster 0: ***Insufficient credit history***
#     - young age
#     - moderate loan amount
#     - moderate duration
#     - all gender
#     - mostly non-cc holders
#     - the majority of loan statuses are 'no loan', 'no problems', and 'OK thus far'
#     - withdrawal
#     - mostly household and insurance payments
# - cluster 1: ***student loans***
#     - the youngest age
#     - the largest loan amount
#     - long duration
#     - all gender
#     - mostly non-cc and junior card
#     - the majority of loan statuses are 'no problems', 'OK thus-far', and 'loan not payed'
#     - withdrawal
#     - mostly household and loan payment
# - cluster 2: ***secured debt holders***
#     - young age
#     - moderate loan amount
#     - moderate duration
#     - all gender
#     - mostly classic and gold card
#     - the majority of loan statuses are 'no problems' and 'OK thus-far'
#     - withdrawal
#     - mostly household and insurance payments
# - cluster 3: ***fall behind on payments***
#     - oldest age
#     - the lowest loan amount
#     - short duration
#     - all gender
#     - mostly non cc
#     - no loan status
#     - collection from another bank
#     - credit
#     - pension
# - cluster 4: ***young debtor women***
#     - young age
#     - the lowest loan amount
#     - short duration
#     - women
#     - mostly non cc and junior card
#     - no loan status
#     - withdrawal
#     - mostly household
# - cluster 5: ***young debtor men***
#     - young age
#     - the lowest loan amount
#     - short duration
#     - men
#     - mostly non cc and junior card
#     - no loan status
#     - withdrawal
#     - mostly household

# %% [markdown]
# #### 12.1.5 Business Recommendation

# %% [markdown]
# - cluster 0: ***Insufficient credit history***
#   - Good candidates
#   - Ask to use credit card
# - cluster 1: ***Student loans***
#   - Need to watch carefully
# - cluster 2: ***Secured debt holders***
#   - Good clients
#   - Ask to add credit card
# - cluster 3: ***Fall behind on payments***
#   - Offer to help with financial planning
# - cluster 4: ***Young debtor women***
#   - Offer some additional services
# - cluster 5: ***Young debtor men***
#   - Offer some additional services

# %% [markdown]
# ### 12.2 K-Means

# %%
customers.head(1)
# Out:
#        type_account         frequency client_gender  client_age_1999  \
# 124660        OWNER  MONTHLY ISSUANCE         Women               20
#
#             type_card    Region Name  Average salary  amount_loan  duration  \
# 124660  non cc holder  south Moravia          8441.0          0.0       0.0
#
#         payments status  amount_order        type                   operation  \
# 124660       0.0      N         668.0  Withdrawal  Remittance to Another Bank
#
#         amount  balance           k_symbol bank  clusters
# 124660  1075.0  24963.1  Insurance Payment   EF         3

# %%
customers_std.head(1)
# Out:
#         type_account  client_gender  client_age_1999  type_card  \
# 124660     -0.478662       1.005038        -1.580831   0.403966
#
#         Average salary  amount_loan  duration  payments    status  \
# 124660        0.074701          0.0       0.0       0.0  0.562861
#
#         amount_order      type  operation    amount   balance  \
# 124660      0.044822  0.349543   0.349543  0.072519  0.225267
#
#         frequency_ISSUANCE AFTER TRANSACTION  frequency_MONTHLY ISSUANCE  \
# 124660                                     0                           1
#
#         frequency_WEEKLY ISSUANCE  Region Name_Prague  \
# 124660                          0                   0
#
#         Region Name_central Bohemia  Region Name_east Bohemia  \
# 124660                            0                         0
#
#         Region Name_north Bohemia  Region Name_north Moravia  \
# 124660                          0                          0
#
# ...

# %%
customers2 = customers.drop(['clusters'], axis=1)
customers_std2 = customers_std.drop(['clusters'], axis=1)

# %%
from sklearn import cluster

# %% [markdown]
# #### 12.2.1 Determine Cluster Number

# %% [markdown]
# ***elbow method***

# %%
distortions = []
K = range(2,11)
for k in K:
    kmeanModel = cluster.KMeans(n_clusters=k)
    kmeanModel.fit(customers_std2)
    distortions.append(kmeanModel.inertia_)

plt.figure(figsize=(13,7))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# #### 12.2.2 Modelling

# %%
cluster_model = cluster.KMeans(n_clusters=6, random_state=42)
cluster_model.fit(customers_std2)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
customers_std2['clusters'] = cluster_model.labels_
customers2['clusters'] = cluster_model.labels_

# %%
customers2.head(3)
# Out:
#        type_account         frequency client_gender  client_age_1999  \
# 124660        OWNER  MONTHLY ISSUANCE         Women               20
# 369329        OWNER  MONTHLY ISSUANCE         Women               21
# 230236        OWNER  MONTHLY ISSUANCE         Women               28
#
#             type_card      Region Name  Average salary  amount_loan  duration  \
# 124660  non cc holder    south Moravia          8441.0          0.0       0.0
# 369329         junior           Prague         12541.0     390660.0      60.0
# 230236  non cc holder  central Bohemia          8507.0          0.0       0.0
#
#         payments status  amount_order        type                   operation  \
# 124660       0.0      N         668.0  Withdrawal  Remittance to Another Bank
# 369329    6511.0      C       10755.0  Withdrawal  Remittance to Another Bank
# 230236       0.0      N         655.0  Withdrawal  Remittance to Another Bank
#
#         amount  balance           k_symbol bank  clusters
# ...

# %%
# from google.colab import files
# customers.to_excel ("kmeans cc analysis.xlsx", index = False, header=True) 
# files.download('kmeans cc analysis.xlsx')

# %% [markdown]
# #### 12.2.3 Interpret The Segment

# %%
customers2.groupby(['clusters'])['client_age_1999','Average salary','amount_loan','duration','payments'].agg(['count','mean']).T
# Out:
# clusters                         0            1              2            3  \
# client_age_1999 count   914.000000   455.000000     739.000000   883.000000
#                 mean     43.905908    72.362637      40.550744    47.796149
# Average salary  count   914.000000   455.000000     739.000000   883.000000
#                 mean   9621.106127  9486.470330    9519.380244  9469.740657
# amount_loan     count   914.000000   455.000000     739.000000   883.000000
#                 mean   9043.299781     0.000000  143004.357240  4718.663647
# duration        count   914.000000   455.000000     739.000000   883.000000
#                 mean      1.378556     0.000000      36.746955     0.761042
# payments        count   914.000000   455.000000     739.000000   883.000000
#                 mean    171.556893     0.000000    3931.568336   112.562854
#
# clusters                          4             5
# client_age_1999 count    667.000000    521.000000
# ...

# %%
customers2.groupby(['clusters','type_account'])['clusters'].agg(['count'])
# Out:
#                        count
# clusters type_account
# 0        OWNER           914
# 1        OWNER           350
#          USER            105
# 2        OWNER           732
#          USER              7
# 3        OWNER           883
# 4        USER            667
# 5        OWNER           521

# %%
customers2.groupby(['clusters','client_gender'])['clusters'].agg(['count'])
# Out:
#                         count
# clusters client_gender
# 0        Women            914
# 1        Men              231
#          Women            224
# 2        Men              353
#          Women            386
# 3        Men              883
# 4        Men              357
#          Women            310
# 5        Men              276
#          Women            245

# %%
customers2.groupby(['clusters','type_card'])['clusters'].agg(['count'])
# Out:
#                         count
# clusters type_card
# 0        junior            25
#          non cc holder    889
# 1        classic            4
#          gold               4
#          non cc holder    447
# 2        gold               7
#          junior            39
#          non cc holder    693
# 3        junior            36
#          non cc holder    847
# 4        non cc holder    667
# 5        classic          458
#          gold              63

# %%
customers2.groupby(['clusters','status'])['clusters'].agg(['count'])
# Out:
#                  count
# clusters status
# 0        D          24
#          N         890
# 1        N         455
# 2        A         317
#          B          26
#          C         390
#          D           6
# 3        C           5
#          D          13
#          N         865
# 4        A         102
#          C         105
#          N         460
# 5        A          67
#          C          82
#          D           2
#          N         370

# %%
customers2.groupby(['clusters','type'])['clusters'].agg(['count'])
# Out:
#                      count
# clusters type
# 0        Withdrawal    914
# 1        Credit        455
# 2        Withdrawal    739
# 3        Withdrawal    883
# 4        Withdrawal    667
# 5        Withdrawal    521

# %%
customers2.groupby(['clusters','operation'])['clusters'].agg(['count'])
# Out:
#                                        count
# clusters operation
# 0        Remittance to Another Bank      914
# 1        Collection from Another Bank    455
# 2        Remittance to Another Bank      739
# 3        Remittance to Another Bank      883
# 4        Remittance to Another Bank      667
# 5        Remittance to Another Bank      521

# %%
customers2.groupby(['clusters','k_symbol'])['clusters'].agg(['count'])
# Out:
#                             count
# clusters k_symbol
# 0        Household            674
#          Insurance Payment    233
#          Loan Payment           7
# 1        Old-age Pension      455
# 2        Household            336
#          Insurance Payment    138
#          Loan Payment         265
# 3        Household            673
#          Insurance Payment    206
#          Loan Payment           4
# 4        Household            464
#          Insurance Payment    141
#          Loan Payment          62
# 5        Household            345
#          Insurance Payment    126
#          Loan Payment          50
